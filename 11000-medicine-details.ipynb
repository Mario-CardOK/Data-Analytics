# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("singhnavjot2062001/11000-medicine-details")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 763k/763k [00:00<00:00, 864kB/s]
# Extracting model files...
# Path to dataset files: C:\Users\user\.cache\kagglehub\datasets\singhnavjot2062001\11000-medicine-details\versions\87

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:\\Users\\user\\.cache\\kagglehub\\datasets\\singhnavjot2062001\\11000-medicine-details\\versions\\87\\Medicine_Details.csv')

# %%
df.sort_values(by = 'Excellent Review %', ascending = False)
# Out:
#                    Medicine Name  \
# 11788  Zithrocin 200mg/5ml Syrup
# 4475     Lupilyzer Oral Solution
# 4491            Lox 2% Injection
# 11708            Zentob Eye Drop
# 11723        Zynoff Eye/Ear Drop
# ...                          ...
# 11747          Zatura 250 Tablet
# 8798           Ronycold-M Tablet
# 8799             Revas 25 Tablet
# 11823            Zedruff Shampoo
# 3885             Isolor 5 Tablet
#
#                                              Composition  \
# 11788                           Azithromycin (200mg/5ml)
# 4475   Magnesium Citrate (375mg/5ml) + Potassium Citr...
# 4491                                      Lidocaine (2%)
# 11708                              Tobramycin (0.3% w/v)
# 11723                               Ofloxacin (0.3% w/v)
# ...                                                  ...
# 11747                               Azithromycin (250mg)
# 8798           Levocetirizine (5mg) + Montelukast (10mg)
# ...
