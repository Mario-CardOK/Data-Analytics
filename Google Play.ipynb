# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("lava18/google-play-store-apps")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████| 1.94M/1.94M [00:01<00:00, 1.21MB/s]
# Extracting model files...
# Path to dataset files: C:\Users\user\.cache\kagglehub\datasets\lava18\google-play-store-apps\versions\6

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\user\\.cache\\kagglehub\\datasets\\lava18\\google-play-store-apps\\versions\\6\\googleplaystore.csv")

# %%
df[(df['Category'] == 'GAME') & ~(df['Size'] == 'Varies with device')].sort_values(by = 'Size', ascending =False)
# Out:
#                                                     App Category  Rating  \
# 1812                                       Hero Hunters     GAME     4.4
# 1890                                  My Talking Angela     GAME     4.5
# 1697                                  My Talking Angela     GAME     4.5
# 9359  Miraculous Ladybug & Cat Noir - The Official Game     GAME     4.5
# 5408                     Arena of Valor: 5v5 Arena Game     GAME     4.4
# ...                                                 ...      ...     ...
# 6898                                         BW-Go Free     GAME     4.6
# 6895                                              BW-Go     GAME     4.8
# 6721                                   BombSquad Remote     GAME     4.1
# 6910                                           BW-GnuGo     GAME     4.1
# 8084                                        Freecell CY     GAME     4.0
#
#       Reviews  Size      Installs  Type  Price Content Rating  Genres  \
# ...

# %%
df.sort_values(by = 'Installs', ascending = False)
# Out:
#                                                App            Category  \
# 10472      Life Made WI-Fi Touchscreen Photo Frame                 1.9
# 420    UC Browser - Fast Download Private & Secure       COMMUNICATION
# 474                    LINE: Free Calls & Messages       COMMUNICATION
# 3767                  Flipboard: News For Our Time  NEWS_AND_MAGAZINES
# 3574                                   Cloud Print        PRODUCTIVITY
# ...                                            ...                 ...
# 8871                        Test Application DT 02      ART_AND_DESIGN
# 9905                                   Eu sou Rico             FINANCE
# 9934             I'm Rich/Eu sou Rico/أنا غني/我很有錢           LIFESTYLE
# 7434                                 Pekalongan CJ              SOCIAL
# 9148                     Command & Conquer: Rivals              FAMILY
#
#        Rating   Reviews                Size      Installs  Type     Price  \
# ...

# %%
df['Installs'].apply(lambda cnt: (df['Installs'].str[:-1]).str.replace(',',''))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 df['Installs'].apply(lambda cnt: (df['Installs'].str[:-1]).str.replace(',',''))
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\series.py:4943, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4808 def apply(
#    4809     self,
#    4810     func: AggFuncType,
#    (...)
#    4815     **kwargs,
#    4816 ) -> DataFrame | Series:
#    4817     """
#    4818     Invoke function on values of Series.
#    4819
#    (...)
#    4934     dtype: float64
#    4935     """
#    4936     return SeriesApply(
#    4937         self,
#    4938         func,
#    4939         convert_dtype=convert_dtype,
#    4940         by_row=by_row,
#    4941         args=args,
#    4942         kwargs=kwargs,
# -> 4943     ).apply()
#
# ...

# %%
df.groupby('Category')['Installs'].sum()
# Out:
# Category
# 1.9                                                                 Free
# ART_AND_DESIGN         10,000+500,000+5,000,000+50,000,000+100,000+50...
# AUTO_AND_VEHICLES      100,000+1,000,000+100,000+1,000,000+100,000+10...
# BEAUTY                 500,000+1,000,000+100,000+500,000+1,000,000+50...
# BOOKS_AND_REFERENCE    100,000,000+50,000+100,000+10,000,000+100,000,...
# BUSINESS               10,000,000+50,000,000+10,000,000+5,000,000+1,0...
# COMICS                 10,000,000+500,000+1,000,000+500,000+50,000+50...
# COMMUNICATION          1,000,000,000+1,000,000,000+10,000,000+1,000,0...
# DATING                 10,000+1,000+50+100+100+100+10,000,000+10,000,...
# EDUCATION              100,000,000+10,000,000+100,000+5,000,000+10,00...
# ENTERTAINMENT          100,000,000+1,000,000+1,000,000+10,000,000+50,...
# EVENTS                 100,000+5,000,000+500,000+50,000+5,000,000+1,0...
# FAMILY                 50,000,000+10,000,000+100,000,000+1,000,000+5,...
# ...

# %%
df['Installs'] = ((df['Installs'].str[:-1]).str.replace(',',''))
df.drop('')
df.sort_values('Installs')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[89], line 2
#       1 df['Installs'] = ((df['Installs'].str[:-1]).str.replace(',',''))
# ----> 2 df.drop('')
#       3 df.sort_values('Installs')
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)
#    5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)
#    5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
# ...
