# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("C:\\Users\\user\\Documents\\Data-Analytics\\excel\\Mortality in Russia by cause of death  in 2018 (absolute numbers).xlsx")

# %%
df
# Out:
#     Brief nomenclature of causes of death  \
# 0                                       1
# 1                                       2
# 2                                       3
# 3                                       4
# 4                                       5
# ..                                    ...
# 361                                   NaN
# 362                                   NaN
# 363                                   NaN
# 364                                   313
# 365                                   995
#
#                                         Cause of death  In Urban Population  \
# 0                                              Cholera                    0
# 1                                        Typhoid fever                    0
# 2                                          Paratyphoid                    2
# 3                          Other salmonella infections                    8
# ...

# %%
df.sort_values( by = 'In Urban Population', ascending = False)
# Out:
#     Brief nomenclature of causes of death  \
# 358                                   NaN
# 365                                   995
# 179                                   NaN
# 155                                   NaN
# 97                                    NaN
# ..                                    ...
# 49                                     47
# 50                                     48
# 52                                  fifty
# 1                                       2
# 0                                       1
#
#                                         Cause of death  In Urban Population  \
# 358                     TOTAL DEAD (1-245,256-307,315)              1317703
# 365  number of deaths without external causes of death              1218741
# 179              121-155 (Circulatory system diseases)               630394
# 155                   127-133 (Coronary heart disease)               336535
# ...

# %%
df[df['Cause of death'].str.contains('hepatitis')]
# Out:
#     Brief nomenclature of causes of death  \
# 38                                     37
# 39                                     38
# 40                                     39
# 41                                     40
# 42                                     41
# 43                                     42
# 44                                    NaN
# 210                                   182
#
#                                         Cause of death  In Urban Population  \
# 38                                   Acute hepatitis A                    3
# 39                                   Acute hepatitis b                   13
# 40                             Acute viral hepatitis C                   12
# 41                           Chronic viral hepatitis B                  231
# 42                           Chronic viral hepatitis C                 1385
# 43                               Other viral hepatitis                  134
# ...

# %%
df = pd.read_html("C:\\Users\\user\\Downloads\\Купить Квартиру в Москве - 67 429 объявлений о Продаже Квартир Недорого_ Планировки, Цены и Фото – Домклик.html")

# %%
df[0]
# Out:
#                       0                            1
# 0   🟢 Цена недвижимости  от 1,9 млн до 80,9 млн руб.
# 1             🟢 Площадь             от 32 до 115 м2.
# 2          🟢 Цена за м2    от 35 313 до 811 630 руб.
# 3  🟢 Средняя цена за м2                 430 040 руб.
